# %% [markdown]
# ## Examples of MCR etc

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\samia\Desktop\Learning Journey\Machine Learning\Practice\Codes\mlenv\Scripts\python.exe

# %%
import numpy as np 
np.array(3)
# Out:
# array(3)
